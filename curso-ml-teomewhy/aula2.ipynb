# %% [markdown]
# ## Conjunto de Dados do Star Wars 🤖🚀

# %%
import pandas as pd

df = pd.read_parquet("data/dados_clones.parquet")
df
# Out:
#          p2o_master_id  Massa(em kilos) General Jedi encarregado  \
# 0             10578986            83.13                     Yoda
# 1             10976676            83.08                     Yoda
# 2             10588329            83.12                 Shaak Ti
# 3             10254411            83.38                 Shaak Ti
# 4             10634458            83.15                 Shaak Ti
# ...                ...              ...                      ...
# 1048714       10230117            84.14                     Yoda
# 1048715       10230118            83.10                     Yoda
# 1048716       10230119            83.63           Obi-Wan Kenobi
# 1048717       10230120            83.02                 Shaak Ti
# 1048718       10230121            83.92                     Yoda
#
#          Estatura(cm) Distância Ombro a ombro Tamanho do crânio  \
# 0              180.25                  Tipo 4            Tipo 1
# ...

# %% [markdown]
# Tentando entender os parametros dos clones (analise descritiva basica)

# %%
df.groupby(["Status "])[['Estatura(cm)', 'Massa(em kilos)']].mean() 
# resultado mostra que nao existe relacao entre essas variaveis e o status do clone
# Out:
#             Estatura(cm)  Massa(em kilos)
# Status
# Apto          180.605545        83.765887
# Defeituoso    180.400186        83.200134

# %%
# coluna de status em boleano
df['Status_bool'] = df['Status '] == 'Apto'
df
# Out:
#          p2o_master_id  Massa(em kilos) General Jedi encarregado  \
# 0             10578986            83.13                     Yoda
# 1             10976676            83.08                     Yoda
# 2             10588329            83.12                 Shaak Ti
# 3             10254411            83.38                 Shaak Ti
# 4             10634458            83.15                 Shaak Ti
# ...                ...              ...                      ...
# 1048714       10230117            84.14                     Yoda
# 1048715       10230118            83.10                     Yoda
# 1048716       10230119            83.63           Obi-Wan Kenobi
# 1048717       10230120            83.02                 Shaak Ti
# 1048718       10230121            83.92                     Yoda
#
#          Estatura(cm) Distância Ombro a ombro Tamanho do crânio  \
# 0              180.25                  Tipo 4            Tipo 1
# ...

# %%
df.groupby(["Distância Ombro a ombro"])['Status_bool'].mean()
# nao parece ser muito significativo tambem
# Out:
# Distância Ombro a ombro
# Tipo 1    0.894749
# Tipo 2    0.894665
# Tipo 3    0.894456
# Tipo 4    0.895459
# Tipo 5    0.893713
# Name: Status_bool, dtype: float64

# %%
df.groupby(["Tamanho do crânio"])['Status_bool'].mean()
# nao parece ser muito significativo tambem
# Out:
# Tamanho do crânio
# Tipo 1    0.894355
# Tipo 2    0.895701
# Tipo 3    0.895072
# Tipo 4    0.893433
# Tipo 5    0.894483
# Name: Status_bool, dtype: float64

# %%
df.groupby(["Tamanho dos pés"])['Status_bool'].mean()
# nao parece ser muito significativo tambem
# Out:
# Tamanho dos pés
# Tipo 1    0.894781
# Tipo 2    0.894215
# Tipo 3    0.894962
# Tipo 4    0.894309
# Tipo 5    0.894775
# Name: Status_bool, dtype: float64

# %%
df.groupby(["General Jedi encarregado"])['Status_bool'].mean()
# parece ser significativo sim
# Out:
# General Jedi encarregado
# Aayla Secura      1.000000
# Mace Windu        1.000000
# Obi-Wan Kenobi    1.000000
# Shaak Ti          0.765018
# Yoda              0.764945
# Name: Status_bool, dtype: float64

# %% [markdown]
# Criando o Modelo:

# %%
features = [
    "Estatura(cm)",
    "Massa(em kilos)",
    "Distância Ombro a ombro",
    "Tamanho do crânio",
    "Tamanho dos pés",
]

cat_features = ["Distância Ombro a ombro",
                "Tamanho do crânio",
                "Tamanho dos pés"]

X = df[features]

# %% [markdown]
# Transformação das variaveis categoricas em variaveis numericas

# %%
# transformação das variaveis categoricas em numericas
from feature_engine import encoding
onehot = encoding.One   HotEncoder(variables=cat_features)
onehot.fit(X)
X = onehot.transform(X)
X
# Out:
#          Estatura(cm)  Massa(em kilos)  Distância Ombro a ombro_Tipo 4  \
# 0              180.25            83.13                               1
# 1              180.39            83.08                               0
# 2              180.26            83.12                               1
# 3              180.35            83.38                               0
# 4              180.31            83.15                               0
# ...               ...              ...                             ...
# 1048714        181.03            84.14                               0
# 1048715        180.62            83.10                               0
# 1048716        180.54            83.63                               0
# 1048717        180.06            83.02                               0
# 1048718        180.31            83.92                               0
#
#          Distância Ombro a ombro_Tipo 3  Distância Ombro a ombro_Tipo 2  \
# ...

# %%
from sklearn import tree
arvore = tree.DecisionTreeClassifier(max_depth=3)
arvore.fit(X, df["Status "])

# %%

import matplotlib.pyplot as plt
plt.figure(dpi=400)
tree.plot_tree(arvore,
               class_names=arvore.classes_,
               feature_names=X.columns,
               filled=True,
               )
# %%
# Out:
# [Text(0.6666666666666666, 0.875, 'Massa(em kilos) <= 83.405\ngini = 0.189\nsamples = 1048719\nvalue = [938193, 110526]\nclass = Apto'),
#  Text(0.5, 0.625, 'Estatura(cm) <= 180.555\ngini = 0.436\nsamples = 344571\nvalue = [234045, 110526]\nclass = Apto'),
#  Text(0.5833333333333333, 0.75, 'True  '),
#  Text(0.3333333333333333, 0.375, 'Estatura(cm) <= 180.245\ngini = 0.497\nsamples = 205177\nvalue = [94651, 110526]\nclass = Defeituoso'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 53107\nvalue = [53107, 0]\nclass = Apto'),
#  Text(0.5, 0.125, 'gini = 0.397\nsamples = 152070\nvalue = [41544, 110526]\nclass = Defeituoso'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 139394\nvalue = [139394, 0]\nclass = Apto'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 704148\nvalue = [704148, 0]\nclass = Apto'),
#  Text(0.75, 0.75, '  False')]
